# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag, FreqDist
# Download required resources (run once)
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger_eng')
# Input resume text
text = input("Enter resume text: ")
# 1. Tokenization
tokens = word_tokenize(text)
# Keep only alphabetic words and convert to lowercase
words = [word.lower() for word in tokens if word.isalpha()]
print("Tokens:")
print(words)
# 2. Stopword Removal
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word not in stop_words]
print("\nAfter Stopword Removal:")
print(filtered_words)
# 3. Stemming
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
print("\nStemmed Words:")
print(stemmed_words)
# 4. Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
print("\nLemmatized Words:")
print(lemmatized_words)
# 5. POS Tagging
pos_tags = pos_tag(lemmatized_words)
print("\nPOS Tags:")
print(pos_tags)
# 6. Frequency Distribution
freq_dist = FreqDist(lemmatized_words)
print("\nFrequency Distribution:")
for word, freq in freq_dist.items():
    print(word, ":", freq)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\rraka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rraka\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rraka\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\rraka\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\rraka\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\rraka\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# Enter resume text:  Experienced Data Analyst with skills in Python, Machine Learning, Data Visualization, SQL, and Artificial Intelligence. Worked on predictive analytics projects and business intelligence solutions.
# Tokens:
# ['experienced', 'data', 'analyst', 'with', 'skills', 'in', 'python', 'machine', 'learning', 'data', 'visualization', 'sql', 'and', 'artificial', 'intelligence', 'worked', 'on', 'predictive', 'analytics', 'projects', 'and', 'business', 'intelligence', 'solutions']
#
# After Stopword Removal:
# ['experienced', 'data', 'analyst', 'skills', 'python', 'machine', 'learning', 'data', 'visualization', 'sql', 'artificial', 'intelligence', 'worked', 'predictive', 'analytics', 'projects', 'business', 'intelligence', 'solutions']
#
# Stemmed Words:
# ['experienc', 'data', 'analyst', 'skill', 'python', 'machin', 'learn', 'data', 'visual', 'sql', 'artifici', 'intellig', 'work', 'predict', 'analyt', 'project', 'busi', 'intellig', 'solut']
#
# Lemmatized Words:
# ['experienced', 'data', 'analyst', 'skill', 'python', 'machine', 'learning', 'data', 'visualization', 'sql', 'artificial', 'intelligence', 'worked', 'predictive', 'analytics', 'project', 'business', 'intelligence', 'solution']
#
# POS Tags:
# [('experienced', 'VBN'), ('data', 'NNS'), ('analyst', 'NN'), ('skill', 'NN'), ('python', 'FW'), ('machine', 'NN'), ('learning', 'VBG'), ('data', 'NNS'), ('visualization', 'NN'), ('sql', 'VBP'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('worked', 'VBD'), ('predictive', 'JJ'), ('analytics', 'NNS'), ('project', 'NN'), ('business', 'NN'), ('intelligence', 'NN'), ('solution', 'NN')]
#
# Frequency Distribution:
# experienced : 1
# data : 2
# analyst : 1
# skill : 1
# python : 1
# machine : 1
# learning : 1
# visualization : 1
# sql : 1
# artificial : 1
# intelligence : 2
# worked : 1
# predictive : 1
# analytics : 1
# project : 1
# business : 1
# solution : 1
